# %%
output_dir = '/output/'

# %%
import spacy
nlp = spacy.load(output_dir)

# %%
import os
path = os.environ.get('DATA_PATH')
attribute_keys = ['attribute1', 'attribute2']
cols = [('attribute1', 'value1'), ('attribute2', 'value2')]

# %%
from src.utils.data_transformations import dataframe_for_two_attributes
dataframe_for_two_attributes()
# Out:
# [INFO] Loading used combinations data...
# [INFO] Loading descriptions data...
# Saved data to cache: used_combinations.pkl
# [INFO] Loading attributes data...
# Saved data to cache: descriptions.pkl
# Saved data to cache: attributes.pkl
# Saved data to cache: merged_data.pkl
#           ProductID                                 ProductDescription  \
# 1      6.000003e+09  Collegeblock Bebop A4 80BL kariert schwarz  45...
# 2      6.000003e+09  Collegeblock Bebop A4 80BL lin blau  4595-00-3...
# 3      6.000003e+09  Collegeblock Bebop A4 80BL lin blau  4597-00-3...
# 4      6.000003e+09  Collegeblock Bebop A4 80BL lin schwarz  4597-0...
# 5      6.000003e+09  Collegeblock Bebop A4 80BL lin weiß  4597-00-0...
# ...             ...                                                ...
# 22940  6.000113e+09  Inkjetpatrone T40C XD2 cyan EPSON C13T40C240 I...
# 22942  6.000113e+09  Inkjetpatrone T41R3 magenta   Inhalt 110ml, pa...
# ...

# %%
from src.data_processing.data_loader import DataLoader
from sklearn.model_selection import train_test_split

df = dataframe_for_two_attributes()
train_data, test_data = train_test_split(df, test_size=0.2, random_state=42, stratify=df[attribute_keys])
# Out:
# Loaded data from cache: merged_data.pkl

# %%
train_data
# Out:
#           ProductID                                 ProductDescription  \
# 5380   6.000066e+09  Lasertoner CLT-Y5082L HY gelb HP SU532A Kapazi...
# 13292  6.000097e+09  Dual Brush Pen kobaltblau TOMBOW TOABTP-535 Al...
# 20309  6.000109e+09  Zeichenmappe Pinsel A2 RNK 45325 Zeichenmappe ...
# 2462   6.000033e+09  Lasertoner 039 schwarz CANON 0287C001 Kapazitä...
# 13183  6.000097e+09  Spiralblock A5 Wild Animals Luchs HERLITZ 5002...
# ...             ...                                                ...
# 1634   6.000029e+09  Inkjetpatrone Nr. 16 schwarz, cyan, magenta, g...
# 6955   6.000086e+09  Lasertoner gelb   1251C002 046HY EMSTAR C680 K...
# 543    6.000004e+09  Inkjetpatrone Nr.953 schwarz HP L0S58AE Kapazi...
# 8617   6.000089e+09  Schultaschenset Pink Cubes   Midi Plus 13Lt. H...
# 3525   6.000035e+09  Lasertoner magenta   MX27GTMA EMSTAR S726 Komp...
#
#                          AttributeKey1  \
# 5380                             Farbe
# ...

# %%
test_data['attribute1'].value_counts()

# %%
from src.baselines.ner import CustomNerTrainer

trainer = CustomNerTrainer(train_data, test_data)
trainer.train_custom_ner()
trainer.save_model()
# Out:
# C:\Users\Public\anaconda\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Lasertoner 039 schwarz CANON 0287C001 Kapazität ca..." with entities "[(36, 37, 'Anzahl der Farben'), (15, 22, 'Farbe')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\Public\anaconda\lib\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Spiralblock A5 Wild Animals Luchs HERLITZ 50027767..." with entities "[(59, 62, 'Anzahl der Blätter'), (51, 58, 'Ausführ...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...

# %%
doc=nlp(test_data['text'].iloc[15])
test_data.iloc[15]
# Out:
# ProductID                                                  6000089444.0
# ProductDescription    Ordner A4 8cm Ladylike Flowers HERLITZ 5002165...
# AttributeKey1                             Ausführung der Ablagemechanik
# AttributeValue1                                           Hebelmechanik
# AttributeKey2                           Beschreibung der Besonderheiten
# AttributeValue2       Qualitäts-Hebelmechanik mit extremer Zuhaltekraft
# Name: 8741, dtype: object

# %%
doc
# Out:
# Ordner A4 8cm Ladylike Flowers HERLITZ 50021659 maX.file Ordner maX.file A4 8cm Ladylike Flowers. Material der Kaschierung außen/innen: Bilderdruckpapier cellophaniert/Papier schwarz. Qualitäts-Hebelmechanik mit extremer Zuhaltekraft. Ausführung: S80, Hebelmechanik, Griffloch vorhanden, Schlitze vorhanden. Verwendung für Papierformate: A4. Größe (B x H): 285 x 318 mm. Breite des Rückens: 80 mm. Farbe/Farbe des Rückens: Motiv Ladylike Flowers/Motiv Ladylike Flowers. Ladylike Flowers. Art der Verpackung und Inhalt: unverpackt mit 1 Stück.

# %%
for ent in doc.ents:
    print(ent.label_, ent.text)
# Out:
# Beschreibung der Besonderheiten Qualitäts-Hebelmechanik mit extremer Zuhaltekraft
# Ausführung der Ablagemechanik Hebelmechanik
# Breite 285

# %%
test_attribute=test_data.query("`attribute1`=='Breite des Schildes'")

# %%
doc=nlp(test_attribute['text'].iloc[0])
test_attribute.iloc[5]['text']
# Out:
# 'Inkjetpatrone PFI-307Y gelb CANON 9814B001 Kapazität 330ml, passend für Canon imagePROGRAF IPF830, imagePROGRAF IPF840, imagePROGRAF IPF850, Ink yellow'

# %%
metrics={}
for attribute_key in test_data['attribute1'].unique():
    test_attribute=test_data.query("`attribute1`==@attribute_key")
    _, accuracy=eval(test_attribute,attribute_key)
    print(attribute_key,' :',accuracy)
    metrics[attribute_key]=round(accuracy,2)
import json
with open("ner_metrics",'w') as file:
    json.dump(metrics,file)
# Out:
# Anzahl der Farben  : 0.01443298969072165
# Anzahl der Blätter  : 0.28368794326241137
# Bezeichnung der Schreibflüssigkeit  : 0.4857142857142857
# Beschreibung der Besonderheiten  : 0.41624365482233505
# Ausführung der Sortimentszugabe  : 0.625
# Breite  : 0.5418994413407822
# Art des Motivs (Typ)  : 0.3333333333333333
# Anzahl der Blätter je Packung  : 0.3253012048192771
# Ausführung der Feder  : 0.5031446540880503
# Anzahl der Seiten  : 0.9515151515151515
# Anzahl der Hüllen  : 0.6923076923076923
# Farbe des Rahmens  : 0.42857142857142855
# Ausführung der Schaftform  : 0.8508771929824561
# Ausführung der Lineatur  : 0.8095238095238095
# Anzahl der Gelenke  : 0.0
# Farbe  : 0.7601156069364162
# Art des Verschlusses  : 0.5232558139534884
# Ausführung der Tür  : 1.0
# Bezeichnung der Härte  : 0.5555555555555556
# Ausführung der Griffzone  : 0.8982035928143712
# Art des Anschlusses  : 0.25
# Ausführung der Ablagemechanik  : 0.8051948051948052
# Breite der Tafel  : 0.05084745762711865
# ...

# %%
y=test_attribute['value1']
y_pred=test_attribute['prediction']

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

accuracy = accuracy_score(y, y_pred)
precision = precision_score(y, y_pred,average='macro')
recall = recall_score(y, y_pred,average='macro')
f1 = f1_score(y, y_pred,average='macro')
# Out:
# C:\Users\Public\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Public\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(accuracy,precision,recall,f1)
# Out:
# 0.7601156069364162 0.6513636435714358 0.6127076084554091 0.6273181146179323

# %%
import seaborn as sns
import random

labels = train_data['attribute1'].unique()
num_labels = len(labels)
color_palette = sns.color_palette("hls", n_colors=num_labels)
random.shuffle(color_palette)
label_color_mapping = {}
for label, color in zip(labels, color_palette):
    hex_color = "#{:02x}{:02x}{:02x}".format(int(color[0] * 255), int(color[1] * 255), int(color[2] * 255))
    label_color_mapping[label] = hex_color

# %%
label_color_mapping={'Breite': '#dbcd56','Ausführung der Ablagemechanik': '#93db56','Beschreibung der Besonderheiten': '#dbc556' }

# %%
from spacy import displacy

options = {"ents": [ent.label_ for ent in doc.ents], "colors": label_color_mapping}
displacy.render(doc, style="ent", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ordner A4 8cm Ladylike Flowers HERLITZ 50021659 maX.file Ordner maX.file A4 8cm Ladylike Flowers. Material der Kaschierung außen/innen: Bilderdruckpapier cellophaniert/Papier schwarz.
# <mark class="entity" style="background: #db565f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Qualitäts-Hebelmechanik mit extremer Zuhaltekraft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">Beschreibung der Besonderheiten</span>
# </mark>
# . Ausführung: S80,
# <mark class="entity" style="background: #6f56db; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hebelmechanik
# ...
